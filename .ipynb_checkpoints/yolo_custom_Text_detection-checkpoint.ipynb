# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import re

# %%
def display_image(img,title='Image'):
    
    channel = len(img.shape)
    
    if channel <= 2:
        plt.imshow(img, cmap='gray')
        plt.title(title)
        plt.axis('off')
    else:
        img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        plt.imshow(img)
        plt.title(title)
        plt.axis('off')

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet
# Out:
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet

# %%
# %cd ./src/
# Out:
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/src

# %%
# !cp ./detector_b.c ./detector.c

# %%
# !make
# Out:
# chmod +x *.sh
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/detector.c -o obj/detector.o
# ./src/detector.c: In function ‘train_detector’:
# ./src/detector.c:238:13: warning: variable ‘draw_precision’ set but not used [-Wunused-but-set-variable]
#          int draw_precision = 0;
#              ^~~~~~~~~~~~~~
# ./src/detector.c: In function ‘validate_detector_map’:
# ./src/detector.c:1010:15: warning: unused variable ‘class_recall’ [-Wunused-variable]
#          float class_recall = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)(truth_classes_count[i] - tp_for_thresh_per_class[i]));
#                ^~~~~~~~~~~~
# ./src/detector.c:1009:15: warning: unused variable ‘class_precision’ [-Wunused-variable]
# ...

# %%
# change the permission mode
# !chmod +x ./darknet

# %%
./darknet detector test cfg/coco.data cfg/yolov3.cfg yolov3.weights data/dog.jpg

# %%
# !pwd
# Out:
# /content

# %%
text_path= '/content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/text/*.txt'

# %%
text_path_list = glob.glob(text_path)
print(len(text_path_list))
# Out:
# 100

# %%
split_ratio = .8
train_size= int(len(text_path_list)*split_ratio)
print(train_size)
train_path = text_path_list[0:train_size]
test_path = text_path_list[train_size:]
print(len(train_path), len(test_path))
# Out:
# 80
# 80 20

# %%
print(train_path[0])
# Out:
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/text/X51005301659(3).txt

# %%
work_path ='/content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/'
with open(work_path+'custom.names', 'w') as file:
  file.writelines('text')

# %%
with open(work_path+'train.txt','w') as file:
  for idx, path in enumerate(train_path,1):
    path=re.sub('text','image',path)
    path=re.sub('txt','jpg',path)
    print(path)
    file.writelines(path+'\n')
# Out:
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/image/X51005301659(3).jpg
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/image/X51005268400.jpg
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/image/X51005361895(1).jpg
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/image/X51005301659(2).jpg
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/image/X00016469623.jpg
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/image/X51005301667(1).jpg
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/image/X51005361883.jpg
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/image/X51005301661.jpg
# ...

# %%
with open(work_path+'test.txt','w') as file:
  for idx, path in enumerate(test_path,1):
    path=re.sub('text','image',path)
    path=re.sub('txt','jpg',path)
    print(path)
    file.writelines(path+'\n')
# Out:
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/image/X51005442361.jpg
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/image/X51005453729.jpg
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/image/X51005433552.jpg
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/image/X51005433522.jpg
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/image/X51005447861.jpg
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/image/X51005447861(1).jpg
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/image/X51005433541.jpg
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/image/X51005442397.jpg
# ...

# %%
data ='''classes=1
train=custom_data_yolo/train.txt
valid=custom_data_yolo/test.txt
names=custom_data_yolo/custom.names
backup=custom_data_yolo/'''

with open(work_path+'detector.data','w') as file:
  file.writelines(data)

# %%
with open(work_path+'detector.data','r') as file:
  print(file.read())
# Out:
# classes=1
# train=custom_data/train.txt
# valid=custom_data_yolo/test.txt
# names=custom_data_yolo/custom.names
# backup=custom_data_yolo/

# %%
# %cd ..
# Out:
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation

# %%
pwd
# Out:
# '/content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation'

# %%
# change the permission mode
# !chmod +x ./darknet

# %%
# !./darknet detector train custom_data_yolo/detector.data custom_data_yolo/yolov3-custom.cfg darknet53.conv.74
# Out:
# CUDA status Error: file: ./src/dark_cuda.c : () : line: 36 : build time: May 11 2020 - 15:14:04
# CUDA Error: no CUDA-capable device is detected
# CUDA Error: no CUDA-capable device is detected: Success
# darknet: ./src/utils.c:293: error: Assertion `0' failed.

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet
# Out:
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet

# %%
# change the permission mode
# !chmod +x ./darknet

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2020-05-11 07:15:28--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M   326KB/s    in 9m 30s
#
# 2020-05-11 07:25:00 (278 KB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet
# Out:
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet

# %%
# Execute darknet using YOLOv3 model with pre-trained weights to detect objects on 'dog.jpg'
# !./darknet detect cfg/yolov3.cfg ./yolov3.weights data/dog.jpg -dont-show

# !./darknet detect custom_data_yolo/yolov3-custom.cfg custom_data_yolo/yolov3-custom_last.weights /content/drive/My Drive/Bill.jpeg

# %%
with open('training_log.txt', 'r') as file:
  print(file.read())

# %%
# !ls -a | tee output.file

# %%
# !ls
# Out:
# 3rdparty	CMakeSettings.json	include		       results
# appveyor.yml	custom_data_yolo	json_mjpeg_streams.sh  scripts
# backup		darknet			LICENSE		       src
# bad_label.list	darknet53.conv.74	Makefile	       training_log.txt
# bad.list	DarknetConfig.cmake.in	Makefile_b	       video_v2.sh
# build		darknet.py		net_cam_v3.sh	       video_yolov3.sh
# build.ps1	darknet_video.py	obj		       yolov3.weights
# cfg		data			output.file
# cmake		image_yolov2.sh		predictions.jpg
# CMakeLists.txt	image_yolov3.sh		README.md

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet
# Out:
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet

# %%
# change the permission mode
# !chmod +x ./darknet

# %%
# !./darknet detector train custom_data_yolo/detector.data custom_data_yolo/yolov3-custom.cfg custom_data_yolo/yolov3-custom_last.weights
# Out:
# CUDA status Error: file: ./src/dark_cuda.c : () : line: 36 : build time: May 11 2020 - 15:14:04
# CUDA Error: no CUDA-capable device is detected
# CUDA Error: no CUDA-capable device is detected: Success
# darknet: ./src/utils.c:293: error: Assertion `0' failed.

# %%
# !./darknet detector train custom_data_yolo/detector.data custom_data_yolo/yolov3-custom.cfg custom_data_yolo/yolov3-custom_last.weights
# Out:
# Streaming output truncated to the last 5000 lines.
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000003, .5R: -nan, .75R: -nan,  count: 0
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: 0.874024, Class: 0.999861, Obj: 0.879768, No Obj: 0.001620, .5R: 1.000000, .75R: 1.000000,  count: 2
# Region 106 Avg IOU: 0.811369, Class: 0.999810, Obj: 0.940319, No Obj: 0.001253, .5R: 1.000000, .75R: 0.900000,  count: 10
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000022, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.852434, Class: 0.999988, Obj: 0.989891, No Obj: 0.000194, .5R: 1.000000, .75R: 1.000000,  count: 1
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000004, .5R: -nan, .75R: -nan,  count: 0
# ...

# %%
# !./darknet detector train custom_data_yolo/detector.data custom_data_yolo/yolov3-custom.cfg custom_data_yolo/yolov3-custom_3600.weights -dont-show
# Out:
# Streaming output truncated to the last 5000 lines.
# Region 94 Avg IOU: 0.693786, Class: 0.999825, Obj: 0.497202, No Obj: 0.000522, .5R: 1.000000, .75R: 0.000000,  count: 1
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000039, .5R: -nan, .75R: -nan,  count: 0
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: 0.760711, Class: 0.999629, Obj: 0.975754, No Obj: 0.000450, .5R: 1.000000, .75R: 1.000000,  count: 1
# Region 106 Avg IOU: 0.814586, Class: 0.999676, Obj: 0.958097, No Obj: 0.001579, .5R: 1.000000, .75R: 0.750000,  count: 16
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000003, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000001, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.673657, Class: 0.999707, Obj: 0.868647, No Obj: 0.001289, .5R: 0.937500, .75R: 0.312500,  count: 16
# ...

# %%
# !./darknet detector train custom_data_yolo/detector.data custom_data_yolo/yolov3-custom.cfg custom_data_yolo/yolov3-custom_3300.weights > training_log.txt 2>&1

# %%
# !./darknet detector train custom_data_yolo/detector.data custom_data_yolo/yolov3-custom.cfg custom_data_yolo/yolov3-custom_3300.weights -dont-show
# Out:
# CUDA status Error: file: ./src/dark_cuda.c : () : line: 36 : build time: May 11 2020 - 15:14:04
# CUDA Error: no CUDA-capable device is detected
# CUDA Error: no CUDA-capable device is detected: Success
# darknet: ./src/utils.c:293: error: Assertion `0' failed.

# %%
import argparse

import cv2
import numpy as np
import matplotlib.pyplot as plt
with open('/content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/test.txt', 'r') as file:
  data = file.read()
img_path = data.split('\n')[0:-1]
print(img_path[-1])
# Out:
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/image/X00016469612.jpg

# %%
# parser = argparse.ArgumentParser(add_help=False)
# parser.add_argument("--image", default='samples/image.jpg', help="image for prediction")
# parser.add_argument("--config", default='cfg/yolov3.cfg', help="YOLO config path")
# parser.add_argument("--weights", default='yolov3.weights', help="YOLO weights path")
# parser.add_argument("--names", default='data/coco.names', help="class names path")
# args = parser.parse_args()
config='/content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/yolov3-custom.cfg'
# weights='/content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/yolov3-custom_2400.weights'
weights='/content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/yolov3-custom_last.weights'
names='/content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/custom.names'


CONF_THRESH, NMS_THRESH = 0.5, 0.5

# Load the network
# net = cv2.dnn.readNetFromDarknet(args.config, args.weights)
net = cv2.dnn.readNetFromDarknet(config, weights)
net.setPreferableBackend(cv2.dnn.DNN_BACKEND_OPENCV)
net.setPreferableTarget(cv2.dnn.DNN_TARGET_CPU)

# Get the output layer from YOLO
layers = net.getLayerNames()
output_layers = [layers[i[0] - 1] for i in net.getUnconnectedOutLayers()]

# Read and convert the image to blob and perform forward pass to get the bounding boxes with their confidence scores
# img = cv2.imread(args.image)

# %%
#11,10,12,17
idx=12
# image = img_path[idx]
image = '/content/drive/My Drive/Bill.jpeg'
img = cv2.imread(image)
height, width = img.shape[:2]

blob = cv2.dnn.blobFromImage(img, 0.00392, (416, 416), swapRB=True, crop=False)
net.setInput(blob)
layer_outputs = net.forward(output_layers)

class_ids, confidences, b_boxes = [], [], []
for output in layer_outputs:
    for detection in output:
        scores = detection[5:]
        class_id = np.argmax(scores)
        confidence = scores[class_id]

        if confidence > CONF_THRESH:
            center_x, center_y, w, h = (detection[0:4] * np.array([width, height, width, height])).astype('int')

            x = int(center_x - w / 2)
            y = int(center_y - h / 2)

            b_boxes.append([x, y, int(w), int(h)])
            confidences.append(float(confidence))
            class_ids.append(int(class_id))

# Perform non maximum suppression for the bounding boxes to filter overlapping and low confident bounding boxes
indices = cv2.dnn.NMSBoxes(b_boxes, confidences, CONF_THRESH, NMS_THRESH).flatten().tolist()

# Draw the filtered bounding boxes with their class to the image
# with open(args.names, "r") as f:
with open(names, "r") as f:
    classes = [line.strip() for line in f.readlines()]
colors = np.random.uniform(0, 255, size=(len(classes), 3))

for index in indices:
    x, y, w, h = b_boxes[index]
    # cv2.rectangle(img, (x, y), (x + w, y + h), colors[index], 2)
    # cv2.putText(img, classes[class_ids[index]], (x + 5, y + 20), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, colors[index], 2)
    cv2.rectangle(img, (x, y), (x + w, y + h), (0,255,0), 2)
    # cv2.putText(img, classes[class_ids[index]], (x + 5, y + 20), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0,255,0), 2)


fig = plt.gcf()
fig.set_size_inches(20, 15)
plt.axis("off")
  #plt.rcParams['figure.figsize'] = [10, 5]
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# cv2.imshow("image", img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# imShow(image)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-5dbe6914ab04> in <module>()
#      28
#      29 # Perform non maximum suppression for the bounding boxes to filter overlapping and low confident bounding boxes
# ---> 30 indices = cv2.dnn.NMSBoxes(b_boxes, confidences, CONF_THRESH, NMS_THRESH).flatten().tolist()
#      31
#      32 # Draw the filtered bounding boxes with their class to the image
#
# AttributeError: 'tuple' object has no attribute 'flatten'

# %%
img = cv2.imread( '/content/drive/My Drive/Bill.jpeg')
fig = plt.gcf()
fig.set_size_inches(20, 15)
plt.axis("off")
  #plt.rcParams['figure.figsize'] = [10, 5]
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
with open('/content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/test.txt', 'r') as file:
  print(file.read())
# Out:
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/image/X51005676549.jpg
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/image/X51005677328(1).jpg
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/image/X51005677328(2).jpg
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/image/X51005677328.jpg
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/image/X51005677329(1).jpg
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/image/X51005677329.jpg
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/image/X51005677331.jpg
# /content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/image/X51005677332.jpg
# ...
