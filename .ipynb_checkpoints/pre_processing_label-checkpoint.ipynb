# %%
import spacy

nlp = spacy.load("en_core_web_sm")

text =f'sanjeev has good heart'

doc=nlp(text)

for token in doc:
    print(token.text, token.pos_)

# %%
import glob
from pdf2image import convert_from_path
import pandas as pd
import pytesseract
from bs4 import BeautifulSoup

# %%
def convert_pdf2image(pdf_path, output_path, poppler_path):
    file_path = glob.glob(pdf_path)
    img_list=[]
    for file in file_path:
        img_name= file.split("\\")[1]
        img_name = output_path+img_name.split(".")[0]+'.png'
        images = convert_from_path(file, 300, poppler_path=poppler_path)
        for image in images:
            image.save(img_name, 'PNG')
            img_list.append(images)
    
    return  img_list

# %%
pdf_path = "C:/Users/Sanjeev/Documents/Python Scripts/Dataset/data_to_work/*.pdf"
poppler_path = 'C:/python_lib/poppler-0.68.0/bin'
outfolder = "C:/Users/Sanjeev/Documents/Python Scripts/Dataset/output/"
img_path = "C:/Users/Sanjeev/Documents/Python Scripts/Dataset/output/*.png"
csv_path ='C:/Users/Sanjeev/Documents/Python Scripts/Dataset/csv/'
tesseract_path ='C:/python_lib/ocr/tesseract.exe'
pytesseract.pytesseract.tesseract_cmd = 'C:/python_lib/ocr/tesseract.exe'

# %%
img_list = convert_pdf2image(pdf_path,outfolder,poppler_path)

# %%
def extract_bbox_info(img_path):
    hocr_data = pytesseract.image_to_pdf_or_hocr(img_path, extension='hocr')
    soup = BeautifulSoup(hocr_data)
    spans = soup.find_all('span', attrs={'class':'ocrx_word'})  # getting the attributes 
    word_bbox_list =[]  
    id=[]
    word=[]
    box =[]
    for span in spans:
        bbox_str=span['title']  # geting bounding box inforamtion 
        bbox_str =bbox_str.split(';')
        bbox =bbox_str[0].split()[1:]
    #     x,y,w,h= *bbox
    #     word_info_list.append([span['id'],span.string,[bbox[1].split()[-1],*bbox]])
#         word_bbox_list.append([span['id'],span.string,
#                                [int(bbox[0]),int(bbox[1]),int(bbox[2]),int(bbox[3])]
#                               ])
        id.append(span['id'])
        word.append(span.string)
        box.append(str([int(bbox[0]),int(bbox[1]),int(bbox[2]),int(bbox[3])]))
#         bbox_width.append((int(bbox[2])-int(bbox[0])))
#         word_info_list.sort(key = lambda sort_value: (sort_value[2][1],sort_value[2][0]))
#     word_info_list.sort(key = lambda sort_value: sort_value[2][1])
    data={'word_id': id,'word':word,'bbox':box,'label':None,'key':None,'value':None}
#     return word_bbox_list, bbox_width, pd.DataFrame(data)
    return pd.DataFrame(data)

# %%
csv_path=

# %%
img_path  = glob.glob(img_path)
df_list =[]
for img in img_path:
    img_name = img.split("\\")[1]
    img_name = csv_path+img_name.split('.')[0]+'.csv'
    df = extract_bbox_info(img)
    df_list.append(df)
    df.to_csv(img_name)
#     break

# %%
len(df_list)
df_list[0]
# Out:
#         word_id      word                      bbox label   key value
# 0      word_1_1  STANDARD     [1425, 74, 1839, 130]  None  None  None
# 1      word_1_2   INVOICE     [1869, 74, 2168, 130]  None  None  None
# 2      word_1_3        Ai      [162, 113, 236, 194]  None  None  None
# 3      word_1_4       gas      [243, 124, 414, 202]  None  None  None
# 4      word_1_5    AIRGAS      [472, 131, 596, 155]  None  None  None
# ..          ...       ...                       ...   ...   ...   ...
# 327  word_1_328         1  [1312, 3235, 1322, 3262]  None  None  None
# 328  word_1_329       oma  [1824, 3222, 1886, 3240]  None  None  None
# 329  word_1_330    oreall  [1895, 3223, 1929, 3265]  None  None  None
# 330  word_1_331    S7-S0S  [1934, 3222, 2218, 3265]  None  None  None
# 331  word_1_332      7716  [2086, 3218, 2151, 3282]  None  None  None
#
# [332 rows x 6 columns]

# %%
print(word_bbox_list)
# Out:
# [['word_1_1', 'STANDARD', [1425, 74, 1839, 130]], ['word_1_2', 'INVOICE', [1869, 74, 2168, 130]], ['word_1_3', 'Ai', [162, 113, 236, 194]], ['word_1_4', 'gas', [243, 124, 414, 202]], ['word_1_5', 'AIRGAS', [472, 131, 596, 155]], ['word_1_6', 'USA,', [610, 131, 682, 160]], ['word_1_7', 'LLC', [697, 131, 754, 155]], ['word_1_8', 'i.', [411, 159, 424, 198]], ['word_1_9', 'PO', [475, 165, 519, 189]], ['word_1_10', 'Box', [532, 165, 586, 189]], ['word_1_11', '9249', [597, 165, 669, 189]], ['word_1_12', 'INVOICE', [1151, 163, 1234, 178]], ['word_1_13', 'DATE', [1242, 163, 1295, 178]], ['word_1_14', 'PAYER', [1413, 163, 1481, 178]], ['word_1_15', 'INVOICE', [1629, 163, 1712, 178]], ['word_1_16', 'NO.', [1720, 163, 1754, 178]], ['word_1_17', 'DUE', [1882, 163, 1924, 178]], ['word_1_18', 'DATE', [1932, 163, 1985, 178]], ['word_1_19', 'PAY', [2169, 163, 2209, 178]], ['word_1_20', 'THIS', [2216, 163, 2262, 178]], ['word_1_21', 'AMOUNT', [2269, 163, 2358, 178]], ['word_1_22', 'an', [162, 215, 185, 228]], ['word_1_23', 'Air', [193, 211, 222, 228]], ['word_1_24', 'Liquide', [230, 211, 307, 233]], ['word_1_25', 'company', [315, 215, 414, 233]], ['word_1_26', 'Marietta,', [474, 198, 599, 227]], ['word_1_27', 'GA', [613, 198, 659, 222]], ['word_1_28', '30065-2249', [679, 198, 854, 222]], ['word_1_29', '01/14/2020|', [1131, 211, 1315, 238]], ['word_1_30', '1723192', [1378, 211, 1518, 239]], ['word_1_31', '|', [1551, 195, 1569, 248]], ['word_1_32', '9097101023', [1589, 211, 1794, 239]], ['word_1_33', '|', [1807, 195, 1825, 248]], ['word_1_34', '02/13/2020', [1841, 211, 2025, 239]], ['word_1_35', '$', [2202, 209, 2220, 242]], ['word_1_36', '56.27', [2234, 211, 2324, 238]], ['word_1_37', 'Manage', [1129, 289, 1295, 332]], ['word_1_38', 'Your', [1309, 289, 1414, 323]], ['word_1_39', 'Account', [1427, 289, 1610, 323]], ['word_1_40', 'Online', [1625, 289, 1764, 323]], ['word_1_41', '24/7', [1779, 289, 1866, 323]], ['word_1_42', 'sotDBY', [109, 353, 234, 374]], ['word_1_43', 'AIRGAS', [285, 344, 440, 375]], ['word_1_44', 'USA,', [457, 344, 547, 380]], ['word_1_45', 'LLC', [566, 344, 637, 375]], ['word_1_46', '(S023)', [653, 344, 784, 383]], ['word_1_47', 'Access', [1127, 341, 1246, 368]], ['word_1_48', 'order', [1259, 341, 1346, 368]], ['word_1_49', 'history,', [1358, 341, 1473, 376]], ['word_1_50', 'view', [1488, 341, 1561, 368]], ['word_1_51', 'cylinder', [1574, 341, 1702, 376]], ['word_1_52', 'balances,', [1714, 341, 1869, 373]], ['word_1_53', 'get', [1884, 342, 1935, 376]], ['word_1_54', 'proofs', [1948, 341, 2048, 376]], ['word_1_55', 'of', [2061, 341, 2093, 368]], ['word_1_56', 'delivery,', [2103, 341, 2238, 376]], ['word_1_57', '5125', [287, 388, 376, 419]], ['word_1_58', 'NW', [392, 388, 458, 418]], ['word_1_59', '77TH', [472, 388, 569, 418]], ['word_1_60', 'AVE', [584, 388, 665, 418]], ['word_1_61', 'pay', [1129, 394, 1186, 422]], ['word_1_62', 'invoices', [1200, 387, 1331, 414]], ['word_1_63', 'and', [1345, 387, 1403, 414]], ['word_1_64', 'more', [1418, 394, 1500, 414]], ['word_1_65', '--', [1513, 403, 1536, 406]], ['word_1_66', 'visit', [1548, 387, 1612, 414]], ['word_1_67', 'Airgas.com', [1622, 387, 1808, 422]], ['word_1_68', 'today', [1821, 387, 1911, 422]], ['word_1_69', 'MIAMI', [288, 432, 402, 462]], ['word_1_70', 'FL', [420, 432, 464, 462]], ['word_1_71', '33166-5524', [479, 432, 697, 463]], ['word_1_72', '305-470-8933', [287, 476, 543, 507]], ['word_1_73', 'PLEASE', [1415, 581, 1536, 604]], ['word_1_74', 'MAKE', [1548, 582, 1636, 604]], ['word_1_75', 'CHECKS', [1648, 581, 1777, 604]], ['word_1_76', 'PAYABLE', [1790, 582, 1935, 604]], ['word_1_77', 'AND', [1946, 582, 2011, 604]], ['word_1_78', 'REMIT', [2024, 582, 2118, 604]], ['word_1_79', 'TO:', [2128, 581, 2178, 604]], ['word_1_80', 'BILLTO', [110, 718, 215, 739]], ['word_1_81', 'BOSTON', [288, 710, 457, 741]], ['word_1_82', 'SCIENTIFIC', [474, 710, 702, 741]], ['word_1_83', 'CO', [718, 710, 776, 741]], ['word_1_84', 'CRM', [792, 710, 881, 741]], ['word_1_85', 'LE', [1430, 698, 152 ...
