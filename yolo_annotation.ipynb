# %%
import glob

# %%
p='C:/Users/Sanjeev/Downloads/software/0325updated.task2train(626p)-20200414T125907Z-001/data/label_image/*.txt'

# %%
len(glob.glob(p))
# Out:
# 100

# %%
img_path ='C:/Users/Sanjeev/Downloads/software/0325updated.task2train(626p)-20200414T125907Z-001/0325updated.task2train(626p)/*.jpg'
text_path="C:/Users/Sanjeev/Downloads/software/0325updated.task2train(626p)-20200414T125907Z-001/0325updated.task2train(626p)/*.txt"
img_save_path='C:/Users/Sanjeev/Downloads/software/0325updated.task2train(626p)-20200414T125907Z-001/data/imges/'
text_save_path = 'C:/Users/Sanjeev/Downloads/software/0325updated.task2train(626p)-20200414T125907Z-001/data/text_extract/'

# %%
img_path_list = glob.glob(img_path)
text_path_list = glob.glob(text_path)
print(len(img_path_list))
print(len(text_path_list))
# Out:
# 735
# 876

# %%
img_path_list[0]
# Out:
# 'C:/Users/Sanjeev/Downloads/software/0325updated.task2train(626p)-20200414T125907Z-001/0325updated.task2train(626p)\\X00016469612.jpg'

# %%
import shutil

original = img_path_list[0]
name= img_path_list[0].split("\\")[1]

target = img_save_path+name

shutil.copyfile(original, target)
# Out:
# 'C:/Users/Sanjeev/Downloads/software/0325updated.task2train(626p)-20200414T125907Z-001/data/imges/X00016469612.jpg'

# %%
# copy_data ()-> out data [image_list,ocr_text,out_text,file_name]
def copy_data(img_path_list, text_path_list, data_no=150):
    img_list,ocr_text_list,text_list,file_name_list=[],[],[],[]
    j=0
    for i in range(data_no):
        img_path= img_path_list[i]
        img_name = img_path.split("\\")[-1]
        shutil.copyfile(img_path, img_save_path+img_path.split("\\")[-1])
        img_name=img_name.split('.')[0]
        text_path = text_path_list[j]
        text_name=text_path.split("\\")[-1]
        text_name = text_name.split('.txt')[0]
        while img_name != text_name:
            j +=1
            print('fileName is not same: ',img_name, text_name)
            text_path = text_path_list[j]
            text_name=text_path.split("\\")[-1]
            text_name = text_name.split('.txt')[0]
            
        shutil.copyfile(text_path, text_save_path+text_path.split("\\")[-1])

# %%
read_data(img_path_list,text_path_list,200)
# Out:
# fileName is not same:  X00016469619 X00016469612
# fileName is not same:  X00016469620 X00016469619
# fileName is not same:  X00016469622 X00016469620
# fileName is not same:  X00016469623 X00016469622
# fileName is not same:  X00016469669 X00016469623
# fileName is not same:  X00016469672 X00016469669
# fileName is not same:  X00016469676 X00016469672
# fileName is not same:  X51005200938 X00016469676
# fileName is not same:  X51005230617 X51005200938
# fileName is not same:  X51005255805 X51005230617
# fileName is not same:  X51005268200 X51005255805
# fileName is not same:  X51005268262 X51005268200
# fileName is not same:  X51005268400 X51005268262
# fileName is not same:  X51005268472 X51005268400
# fileName is not same:  X51005301659(1) X51005268472
# fileName is not same:  X51005301659(2) X51005301659(1)
# fileName is not same:  X51005301659(3) X51005301659(2)
# fileName is not same:  X51005301659(4) X51005301659(3)
# fileName is not same:  X51005301659 X51005301659(4)
# ...

# %%
def get_file_path_list(path):
    import glob
    path_list = glob.glob(path)
    print(len(path_list))
#     return path_list

# %%
# from pathlib import Path
path =r'C:/Users/Sanjeev/Downloads/software/0325updated.task2train(626p)-20200414T125907Z-001/data/yolodata/'
# path =Path(path)

# %%
get_file_path_list(path+'*.txt')
# Out:
# 151

# %%
151+151
# Out:
# 302

# %%
 import glob
for i, p in enumerate(zip(glob.glob(path+'*.txt'),glob.glob(path+'*.jpg'))):
    print(i,'-=>', p[0],'\n',p[1])
# Out:
# 0 -=> C:/Users/Sanjeev/Downloads/software/0325updated.task2train(626p)-20200414T125907Z-001/data/yolodata\X00016469612.txt
#  C:/Users/Sanjeev/Downloads/software/0325updated.task2train(626p)-20200414T125907Z-001/data/yolodata\X00016469612.jpg
# 1 -=> C:/Users/Sanjeev/Downloads/software/0325updated.task2train(626p)-20200414T125907Z-001/data/yolodata\X00016469619.txt
#  C:/Users/Sanjeev/Downloads/software/0325updated.task2train(626p)-20200414T125907Z-001/data/yolodata\X00016469619.jpg
# 2 -=> C:/Users/Sanjeev/Downloads/software/0325updated.task2train(626p)-20200414T125907Z-001/data/yolodata\X00016469620.txt
#  C:/Users/Sanjeev/Downloads/software/0325updated.task2train(626p)-20200414T125907Z-001/data/yolodata\X00016469620.jpg
# 3 -=> C:/Users/Sanjeev/Downloads/software/0325updated.task2train(626p)-20200414T125907Z-001/data/yolodata\X00016469622.txt
#  C:/Users/Sanjeev/Downloads/software/0325updated.task2train(626p)-20200414T125907Z-001/data/yolodata\X00016469622.jpg
# ...

# %%
/content/drive/My Drive/Colab Notebooks/Accenture_ML_DL/installation/darknet/custom_data_yolo/image
